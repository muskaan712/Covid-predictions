# %%
# %matplotlib notebook
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.vision import *
from fastai.vision.all import *
from fastai.text.all import *
from fastai.collab import *
from fastai.tabular.all import *

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import average_precision_score
from matplotlib import pyplot
# %matplotlib notebook

# %%
path = ('/home/ccet/Self-Supervised-Learning/covid/archive')

# %%
fnames = get_image_files(path)
def label_func(x): return x.parent.name
data=ImageDataLoaders.from_path_func(path, fnames, label_func,  valid_pct=0.2, seed=None, item_tfms=Resize(224), bs=64)

# %%
learn = cnn_learner(data, models.alexnet, metrics= [accuracy, Precision(average='micro'), F1Score(average='micro')])
# Out:
# Downloading: "https://download.pytorch.org/models/alexnet-owt-4df8aa71.pth" to /home/ccet/.cache/torch/hub/checkpoints/alexnet-owt-4df8aa71.pth
#   0%|          | 0.00/233M [00:00<?, ?B/s]

# %%
learn.fit_one_cycle(6)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>precision_score</th>
#       <th>f1_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.809541</td>
#       <td>0.440006</td>
#       <td>0.840643</td>
#       <td>0.840643</td>
#       <td>0.840643</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.505732</td>
#       <td>0.269648</td>
#       <td>0.905263</td>
#       <td>0.905263</td>
#       <td>0.905263</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.367099</td>
#       <td>0.240189</td>
#       <td>0.914328</td>
#       <td>0.914327</td>
#       <td>0.914327</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.318556</td>
#       <td>0.209860</td>
#       <td>0.923684</td>
#       <td>0.923684</td>
#       <td>0.923684</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.276511</td>
#       <td>0.199469</td>
#       <td>0.928070</td>
#       <td>0.928070</td>
#       <td>0.928070</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.273963</td>
#       <td>0.195507</td>
#       <td>0.929825</td>
#       <td>0.929825</td>
#       <td>0.929825</td>
#       <td>00:12</td>
#     </tr>
#   </tbody>
# </table>

# %%
Interp = ClassificationInterpretation.from_learner(learn)
Interp.plot_confusion_matrix(figsize=(4,4),dpi=120)
# Out:
# <img src="data:image/png;base64,..." width="479.45">
