# %%
# %matplotlib notebook
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.vision import *
from fastai.vision.all import *
from fastai.text.all import *
from fastai.collab import *
from fastai.tabular.all import *

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import average_precision_score
from matplotlib import pyplot
# %matplotlib notebook

# %%
path = ('/home/ccet/Self-Supervised-Learning/0. Rotation/archive/dans-knaw/')

# %%
fnames = get_image_files(path)
def label_func(x): return x.parent.name
data=ImageDataLoaders.from_path_func(path, fnames, label_func,  valid_pct=0.2, seed=None, item_tfms=Resize(224), bs=64)

# %%
learn = cnn_learner(data, models.resnet152, metrics= [accuracy, Precision(average='micro'), F1Score(average='micro')])

# %%
learn.fit_one_cycle(10)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>precision_score</th>
#       <th>f1_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.609218</td>
#       <td>0.331374</td>
#       <td>0.864583</td>
#       <td>0.864583</td>
#       <td>0.864583</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.919651</td>
#       <td>0.134185</td>
#       <td>0.958333</td>
#       <td>0.958333</td>
#       <td>0.958333</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.594957</td>
#       <td>0.061429</td>
#       <td>0.989583</td>
#       <td>0.989583</td>
#       <td>0.989583</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.403553</td>
#       <td>0.065516</td>
#       <td>0.984375</td>
#       <td>0.984375</td>
#       <td>0.984375</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.294291</td>
#       <td>0.055732</td>
#       <td>0.984375</td>
#       <td>0.984375</td>
#       <td>0.984375</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.219071</td>
#       <td>0.039966</td>
#       <td>0.984375</td>
#       <td>0.984375</td>
#       <td>0.984375</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.167553</td>
#       <td>0.029233</td>
#       <td>0.994792</td>
#       <td>0.994792</td>
#       <td>0.994792</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.129776</td>
#       <td>0.025749</td>
#       <td>0.989583</td>
#       <td>0.989583</td>
#       <td>0.989583</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.105036</td>
#       <td>0.025053</td>
#       <td>0.989583</td>
#       <td>0.989583</td>
#       <td>0.989583</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.081763</td>
#       <td>0.020722</td>
#       <td>0.989583</td>
#       <td>0.989583</td>
#       <td>0.989583</td>
#       <td>00:23</td>
#     </tr>
#   </tbody>
# </table>

# %%
# learn.fit_one_cycle(5)

# %%
# learn.fit_one_cycle(5)

# %%
# learn.fit_one_cycle(25)

# %%
# learn.fit_one_cycle(10)

# %%
# learn.fit_one_cycle(15)

# %%
preds,y, loss = learn.get_preds(with_loss=True)
# get accuracy
acc = accuracy(preds, y)
print('The accuracy is {0} %.'.format(acc))
# Out:
# The accuracy is 0.9895833134651184 %.

# %%
from sklearn.metrics import roc_curve, auc
# probs from log preds
probs = np.exp(preds[:,1])
# Compute ROC curve
fpr, tpr, thresholds = roc_curve(y, probs, pos_label=1)

# Compute ROC area
roc_auc = auc(fpr, tpr)
print('ROC area is {0}'.format(roc_auc))
# Out:
# ROC area is 1.0

# %%
plt.figure()
plt.plot(fpr, tpr, color='darkorange', label='ROC curve (area = %0.8f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
plt.xlim([-0.01, 1.0])
plt.ylim([0.0, 1.01])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
# Out:
# <img src="data:image/png;base64,..." width="639.75">
