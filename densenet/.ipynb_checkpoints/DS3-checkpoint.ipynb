# %%
# %matplotlib notebook
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.vision import *
from fastai.vision.all import *
from fastai.text.all import *
from fastai.collab import *
from fastai.tabular.all import *

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import average_precision_score
from matplotlib import pyplot
# %matplotlib notebook

# %%
path = ('/home/ccet/Self-Supervised-Learning/covid/Original-CT-Scans')

# %%
fnames = get_image_files(path)
def label_func(x): return x.parent.name
data=ImageDataLoaders.from_path_func(path, fnames, label_func,  valid_pct=0.2, seed=None, item_tfms=Resize(224), bs=64)

# %%
learn = cnn_learner(data, models.densenet201, metrics= [accuracy, Precision(average='micro'), F1Score(average='micro')])

# %%
learn.fit_one_cycle(6)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>precision_score</th>
#       <th>f1_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.098010</td>
#       <td>0.056385</td>
#       <td>0.983744</td>
#       <td>0.983744</td>
#       <td>0.983744</td>
#       <td>02:02</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.065068</td>
#       <td>0.026199</td>
#       <td>0.990348</td>
#       <td>0.990348</td>
#       <td>0.990348</td>
#       <td>02:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.037602</td>
#       <td>0.026228</td>
#       <td>0.990602</td>
#       <td>0.990602</td>
#       <td>0.990602</td>
#       <td>01:58</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.017180</td>
#       <td>0.021025</td>
#       <td>0.992888</td>
#       <td>0.992888</td>
#       <td>0.992888</td>
#       <td>01:58</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.009619</td>
#       <td>0.011899</td>
#       <td>0.995428</td>
#       <td>0.995428</td>
#       <td>0.995428</td>
#       <td>01:58</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.002456</td>
#       <td>0.012772</td>
#       <td>0.995682</td>
#       <td>0.995682</td>
#       <td>0.995682</td>
#       <td>01:58</td>
#     </tr>
#   </tbody>
# </table>

# %%
Interp = ClassificationInterpretation.from_learner(learn)
Interp.plot_confusion_matrix(figsize=(4,4),dpi=120)
# Out:
# <img src="data:image/png;base64,..." width="479.45">

# %%
preds,y, loss = learn.get_preds(with_loss=True)
# get accuracy
acc = accuracy(preds, y)
print('The accuracy is {0} %.'.format(acc))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-805abb3745f1> in <module>
# ----> 1 preds,y, loss = learn.get_preds(with_loss=True)
#       2 # get accuracy
#       3 acc = accuracy(preds, y)
#       4 print('The accuracy is {0} %.'.format(acc))
#
# NameError: name 'learn' is not defined

# %%
from sklearn.metrics import roc_curve, auc
# probs from log preds
probs = np.exp(preds[:,1])
# Compute ROC curve
fpr, tpr, thresholds = roc_curve(y, probs, pos_label=1)

# Compute ROC area
roc_auc = auc(fpr, tpr)
print('ROC area is {0}'.format(roc_auc))

# %%
plt.figure()
plt.plot(fpr, tpr, color='darkorange', label='ROC curve (area = %0.8f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
plt.xlim([-0.01, 1.0])
plt.ylim([0.0, 1.01])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
